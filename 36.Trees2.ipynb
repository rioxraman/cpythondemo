# %% [markdown]
# Tree Traversals: The session reviewed the three primary types of tree traversals:
# In-order: Left, Node, Right.
# Pre-order: Node, Left, Right.
# Post-order: Left, Right, Node.

# %% [markdown]
# Iterative In-order Traversal: The speaker demonstrated how to perform an in-order traversal using an iterative approach rather than recursion, utilizing a stack to store nodes.
# Level Order Traversal: This method traverses a tree level by level, from top to bottom. It is typically implemented using a queue data structure, ensuring that nodes are processed in a first-in, first-out manner.

# %% [markdown]
# 94. Binary Tree Inorder Traversal
# Solved
# Easy
# Topics
# premium lock icon
# Companies
# Given the root of a binary tree, return the inorder traversal of its nodes' values.
#
#
#
# Example 1:
#
# Input: root = [1,null,2,3]
#
# Output: [1,3,2]

# %%
# Definition for a binary tree node.
# class TreeNode(object):
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution(object):
    def inorderTraversal(self, root):
        """
        :type root: Optional[TreeNode]
        :rtype: List[int]
        """
        ans=[]
        stack=[]
        while root or stack:
            while root:
                stack.append(root)
                root=root.left
            root=stack.pop()
            ans.append(root.val)
            root=root.right
        return ans

# %% [markdown]
# # level order

# %% [markdown]
# Tree Views: The session explained how to visualize the "left view" and "right view" of a tree. This involves processing the nodes in a level-order manner and selecting the first node encountered at each level for the left view, or the last node for the right view.

# %% [markdown]
# Binary Tree Construction: The final technical topic was constructing a binary tree using given pre-order and in-order traversal lists. By identifying the root from the pre-order list and locating its position in the in-order list, the left and right subtrees can be rec
